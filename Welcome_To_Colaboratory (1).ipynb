# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-ad03d2c9-36f2-477f-be88-59e32609bba9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad03d2c9-36f2-477f-be88-59e32609bba9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Caffeine Consumption & Health (Responses) - Form Responses 1.csv')
df.drop(["Timestamp"], axis = 1, inplace = True)
df.head(42)
# Out:
#    On average, how many caffeinated beverages do you consume per day?  \
# 0                                                 1-2
# 1                                                 1-2
# 2                                                 1-2
# 3                                                None
# 4                                                 1-2
# 5                                                 1-2
# 6                                                 1-2
# 7                                                 1-2
# 8                                                 1-2
# 9                                                 3-4
# 10                                               None
# 11                                               None
# 12                                                1-2
# 13                                                1-2
# 14                                               None
# 15                                                1-2
# ...

# %%
import matplotlib.pyplot as plt

# Data
health_effects = ['Anxiety or restlessness',
                  'Difficulty sleeping',
                  'Digestive issues',
                  'Increased heart rate/palpitations',
                  'None']
counts = [13, 26, 11, 20, 7]  # Counts based on provided responses

# Visualization: Health Effects Due to Caffeine Consumption (Bar Chart)
plt.figure(figsize=(10, 6))
plt.bar(health_effects, counts, color='lightgreen')
plt.xlabel('Health Effects')
plt.ylabel('Frequency')
plt.title('Health Effects Due to Caffeine Consumption')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data
caffeine_consumption = ['1-2', '1-2', '1-2', 'None', '1-2', '1-2', '1-2', '1-2', '1-2', '3-4', 'None', 'None', '1-2', '1-2', 'None', '1-2', '1-2', 'None', '5 or more', '1-2', 'None', '1-2', 'None', 'None', '1-2', '1-2', '1-2', '1-2', '1-2', 'None', '1-2', '1-2', '5 or more', '1-2', '1-2', '1-2', '1-2', '1-2', '1-2', '1-2', '1-2', '1-2']
health_effects = ['Anxiety or restlessness', 'Difficulty sleeping, Increased heart rate or palpitations, Anxiety or restlessness, Digestive issues (e.g., stomach upset, acid reflux)', 'Difficulty sleeping', 'None of the above', 'Difficulty sleeping, Digestive issues (e.g., stomach upset, acid reflux)', 'Difficulty sleeping', 'Difficulty sleeping, Increased heart rate or palpitations, Anxiety or restlessness', 'None of the above', 'Increased heart rate or palpitations, Anxiety or restlessness', 'Difficulty sleeping, Increased heart rate or palpitations, Anxiety or restlessness', 'None of the above', 'Difficulty sleeping, Increased heart rate or palpitations, Anxiety or restlessness', 'Digestive issues (e.g., stomach upset, acid reflux)', 'None of the above', 'Difficulty sleeping, Increased heart rate or palpitations, Anxiety or restlessness, Digestive issues (e.g., stomach upset, acid reflux)', 'None of the above', 'None of the above', 'Difficulty sleeping, Increased heart rate or palpitations', 'Difficulty sleeping, Anxiety or restlessness, Digestive issues (e.g., stomach upset, acid reflux)', 'Difficulty sleeping', 'Increased heart rate or palpitations', 'Difficulty sleeping, Increased heart rate or palpitations, Anxiety or restlessness', 'Difficulty sleeping, Increased heart rate or palpitations, Anxiety or restlessness', 'Difficulty sleeping, Anxiety or restlessness, Digestive issues (e.g., stomach upset, acid reflux)', 'Difficulty sleeping, Increased heart rate or palpitations, Anxiety or restlessness', 'None of the above', 'None of the above', 'Increased heart rate or palpitations', 'Difficulty sleeping, Increased heart rate or palpitations, Anxiety or restlessness', 'None of the above', 'Difficulty sleeping, Increased heart rate or palpitations, Anxiety or restlessness, Digestive issues (e.g., stomach upset, acid reflux)', 'Difficulty sleeping, Increased heart rate or palpitations', 'None of the above', 'Anxiety or restlessness', 'None of the above', 'Increased heart rate or palpitations, Digestive issues (e.g., stomach upset, acid reflux)', 'Increased heart rate or palpitations, Digestive issues (e.g., stomach upset, acid reflux)', 'Increased heart rate or palpitations, Digestive issues (e.g., stomach upset, acid reflux)', 'Increased heart rate or palpitations, Digestive issues (e.g., stomach upset, acid reflux)', 'Increased heart rate or palpitations, Digestive issues (e.g., stomach upset, acid reflux)', 'Difficulty sleeping, Increased heart rate or palpitations, Digestive issues (e.g., stomach upset, acid reflux)', 'Difficulty sleeping, Increased heart rate or palpitations']

# Splitting the combined health effects into individual health effects
split_health_effects = [effect.split(', ') for effect in health_effects]

# Flattening the list of lists to get individual health effects
flat_health_effects = [effect for sublist in split_health_effects for effect in sublist]

# Counting occurrences of each health effect for each number of consumed beverages
effect_counts = {}
for caffeine, effects in zip(caffeine_consumption, split_health_effects):
    for effect in effects:
        if effect in effect_counts:
            effect_counts[effect].append(caffeine)
        else:
            effect_counts[effect] = [caffeine]

# Find the maximum length of arrays
max_length = max(len(arr) for arr in effect_counts.values())

# Pad arrays with None to make them of equal length
for arr in effect_counts.values():
    while len(arr) < max_length:
        arr.append(None)

# Convert to DataFrame
df = pd.DataFrame(effect_counts)

# Plotting
df.apply(pd.Series.value_counts).T.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Correlation between Caffeine Consumption and Health Effects')
plt.xlabel('Number of Caffeinated Beverages Consumed per Day')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.legend(title='Health Effects', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
